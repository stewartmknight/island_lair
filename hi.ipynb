# %%
import pandas as pd

# %%
#df = pd.read_excel("Resources/FullDataSet_19.csv")
#df

# %%
df = pd.read_excel("Resources/18_FullDataSet.xlsx")

# %%
df
# Out:
#     Corruption Perceptions Index 2018: Global Scores  Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                                             Country       ISO3     Region
# 2                                             Denmark        DNK      WE/EU
# 3                                         New Zealand        NZL         AP
# 4                                             Finland        FIN      WE/EU
# ..                                                ...        ...        ...
# 177                                      Korea, North        PRK         AP
# 178                                             Yemen        YEM       MENA
# 179                                       South Sudan        SSD        SSA
# 180                                             Syria        SYR       MENA
# 181                                           Somalia        SOM        SSA
#
# ...

# %%
corruption = pd.DataFrame(df)

# %%
corruption
# Out:
#     Corruption Perceptions Index 2018: Global Scores  Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                                             Country       ISO3     Region
# 2                                             Denmark        DNK      WE/EU
# 3                                         New Zealand        NZL         AP
# 4                                             Finland        FIN      WE/EU
# ..                                                ...        ...        ...
# 177                                      Korea, North        PRK         AP
# 178                                             Yemen        YEM       MENA
# 179                                       South Sudan        SSD        SSA
# 180                                             Syria        SYR       MENA
# 181                                           Somalia        SOM        SSA
#
# ...
